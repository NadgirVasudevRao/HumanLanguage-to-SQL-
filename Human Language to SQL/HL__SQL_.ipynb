# %%
import sqlite3
# !pip install langchain-groq

import pandas as pd

# Loading CSV
df = pd.read_csv("/content/drive/MyDrive/Project_Datasets/smartphones.csv.csv")

# Cleaning column names
df.columns = [c.strip().lower().replace(" ", "_") for c in df.columns]

# Connecting to the database
conn = sqlite3.connect("my_db.db")

# Writing to table
df.to_sql("smartphones", conn, if_exists="replace", index=False)

conn.commit()
conn.close()

print("✅ Smartphones data loaded into 'smartphones' table.")
# Out:
# ...
# ✅ Smartphones data loaded into 'smartphones' table.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
df.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %%
# !pip install -U langchain-community
# !pip install -U langchain-groq

from langchain_groq import ChatGroq
from langchain_community.utilities import SQLDatabase
from langchain_community.agent_toolkits import SQLDatabaseToolkit
from langchain.agents import create_sql_agent
import os


# Setting the Groq API key
os.environ["GROQ_API_KEY"] = "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"

# Connecting to SQLite DB
db = SQLDatabase.from_uri("sqlite:///my_db.db")

llm = ChatGroq(temperature=0, model_name="llama3-8b-8192")

# Creating agent
toolkit = SQLDatabaseToolkit(db=db, llm=llm)
agent_executor = create_sql_agent(llm=llm, toolkit=toolkit, verbose=True, max_iterations=10, max_execution_time=300)


# User Input
response = agent_executor.invoke({
    "input": "Show me the top 5 high rated smartphones"
})

print("\n✅ Result:\n", response["output"])
# Out:
# ...
#
#
# > Entering new SQL Agent Executor chain...
# Let's start by listing the tables in the database:
#
# Action: sql_db_list_tables
# Action Input: (empty string)Let's start by listing the tables in the database.
#
# Action: sql_db_list_tables
# Action Input: (empty string)Let's start by listing the tables in the database.
#
# Action: sql_db_list_tables
# Action Input: (empty string)Let's start by listing the tables in the database.
#
# Action: sql_db_list_tables
# Action Input: (empty string)Let's start by listing the tables in the database.
#
# Action: sql_db_list_tables
# Action Input: (empty string)It seems like I'm stuck in an infinite loop!
#
# Let me try again. Here's the correct sequence of actions:
#
# Question: Show me the top 5 high rated smartphones
# Thought: I should look at the tables in the database to see what I can query.  Then I should query the schema of the most relevant tables.
# Action: sql_db_list_tables
# ...
